# %%
#Importing three most important libraries for Data Analysis in Python.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Setting the backend of MATPLOTLIB in Jupyter Notebook as inline.
# %matplotlib inline

# %% [markdown]
# #### A function in Jupyter Notebook to list directories and files

# %%
ls
# Out:
#  Volume in drive F is CS
#  Volume Serial Number is 2CB6-9105
#
#  Directory of F:\PathToDL\DataAnalysis
#
# 04/25/2020  10:17 AM    <DIR>          .
# 04/25/2020  10:17 AM    <DIR>          ..
# 04/25/2020  10:12 AM    <DIR>          .ipynb_checkpoints
# 04/25/2020  10:17 AM           138,729 Hello World!.ipynb
# 04/25/2020  08:58 AM        15,240,280 sales_data.csv
# 04/25/2020  10:14 AM               555 Working with SQL database.ipynb
#                3 File(s)     15,379,564 bytes
#                3 Dir(s)  119,407,427,584 bytes free

# %%
#Reading a files using Pandas.
#read_xlsx and similar other for other forms of filenames
sales = pd.read_csv('sales_data.csv')

# %%
#Look at the few examples of datas in our file
sales.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
#Number of rows and coloums in a database
sales.shape
# Out:
# (113036, 18)

# %%
sales.describe()
# Out:
#                  Day           Year   Customer_Age  Order_Quantity  \
# count  113036.000000  113036.000000  113036.000000   113036.000000
# mean       15.665753    2014.401739      35.919212       11.901660
# std         8.781567       1.272510      11.021936        9.561857
# min         1.000000    2011.000000      17.000000        1.000000
# 25%         8.000000    2013.000000      28.000000        2.000000
# 50%        16.000000    2014.000000      35.000000       10.000000
# 75%        23.000000    2016.000000      43.000000       20.000000
# max        31.000000    2016.000000      87.000000       32.000000
#
#            Unit_Cost     Unit_Price         Profit           Cost  \
# count  113036.000000  113036.000000  113036.000000  113036.000000
# mean      267.296366     452.938427     285.051665     469.318695
# std       549.835483     922.071219     453.887443     884.866118
# min         1.000000       2.000000     -30.000000       1.000000
# ...

# %%
sales['Profit'].describe()
# Out:
# count    113036.000000
# mean        285.051665
# std         453.887443
# min         -30.000000
# 25%          29.000000
# 50%         101.000000
# 75%         358.000000
# max       15096.000000
# Name: Profit, dtype: float64

# %%
sales['Profit'].mean()
# Out:
# 285.0516649562971

# %% [markdown]
# #### Plotting different forms of graphs in pandas.
# Here 'kind =' is used to specify the type of graph to be used
# For more: http://queirozf.com/entries/pandas-dataframe-plot-examples-with-matplotlib-pyplot

# %%
sales['Profit'].plot(kind = 'density')

# %% [markdown]
# Before moving on, try other kinds of diagrams on different coloumns of the sales dataframe.

# %%
sales['Age_Group'].value_counts()
# Out:
# Adults (35-64)          55824
# Young Adults (25-34)    38654
# Youth (<25)             17828
# Seniors (64+)             730
# Name: Age_Group, dtype: int64

# %%
sales['Age_Group'].value_counts().plot(kind = 'pie')

# %%
correlations = sales.corr()

# %%
correlations
# Out:
#                      Day      Year  Customer_Age  Order_Quantity  Unit_Cost  \
# Day             1.000000 -0.007635     -0.014296       -0.002412   0.003133
# Year           -0.007635  1.000000      0.040994        0.123169  -0.217575
# Customer_Age   -0.014296  0.040994      1.000000        0.026887  -0.021374
# Order_Quantity -0.002412  0.123169      0.026887        1.000000  -0.515835
# Unit_Cost       0.003133 -0.217575     -0.021374       -0.515835   1.000000
# Unit_Price      0.003207 -0.213673     -0.020262       -0.515925   0.997894
# Profit          0.004623 -0.181525      0.004319       -0.238863   0.741020
# Cost            0.003329 -0.215604     -0.016013       -0.340382   0.829869
# Revenue         0.003853 -0.208673     -0.009326       -0.312895   0.817865
#
#                 Unit_Price    Profit      Cost   Revenue
# Day               0.003207  0.004623  0.003329  0.003853
# Year             -0.213673 -0.181525 -0.215604 -0.208673
# ...

# %% [markdown]
# ## Working with columns

# %%
#Create a new column called 'Revenue_per_Age'
sales['Revenue_per_Age'] = sales['Revenue'] / sales['Customer_Age']

# %%
sales['Revenue_per_Age'].head()
# Out:
# 0    50.000000
# 1    50.000000
# 2    49.000000
# 3    42.612245
# 4     8.893617
# Name: Revenue_per_Age, dtype: float64

# %%
sales['Revenue_per_Age'].plot(kind = 'hist')

# %% [markdown]
# ### Increase all the unit price by 10%

# %%
#Notice the Unit Price
sales['Unit_Price'].head()
# Out:
# 0    120
# 1    120
# 2    120
# 3    120
# 4    120
# Name: Unit_Price, dtype: int64

# %%
#Notice Unit Prices again
sales['Unit_Price'] = sales['Unit_Price']* 1.10
sales['Unit_Price'].head()
# Out:
# 0    132.0
# 1    132.0
# 2    132.0
# 3    132.0
# 4    132.0
# Name: Unit_Price, dtype: float64

# %% [markdown]
# # Selection and Indexing

# %%
sales.loc[sales['Country'] == 'Canada']
# Out:
#               Date  Day      Month  Year  Customer_Age             Age_Group  \
# 0       2013-11-26   26   November  2013            19           Youth (<25)
# 1       2015-11-26   26   November  2015            19           Youth (<25)
# 14      2013-08-02    2     August  2013            29  Young Adults (25-34)
# 15      2015-08-02    2     August  2015            29  Young Adults (25-34)
# 16      2013-09-02    2  September  2013            29  Young Adults (25-34)
# 17      2015-09-02    2  September  2015            29  Young Adults (25-34)
# 18      2014-01-22   22    January  2014            29  Young Adults (25-34)
# 19      2016-01-22   22    January  2016            29  Young Adults (25-34)
# 20      2014-05-17   17        May  2014            29  Young Adults (25-34)
# 21      2016-05-17   17        May  2016            29  Young Adults (25-34)
# 24      2013-08-25   25     August  2013            49        Adults (35-64)
# ...

# %% [markdown]
# ### Count the number of rows with Country from Canada

# %%
sales.loc[(sales['Country'] == 'Canada')].shape[0]
# Out:
# 14178

# %%
#Of age group < 25
sales.loc[(sales['Country'] == 'Canada') & (sales['Age_Group'] == 'Youth (<25)')].shape[0]
# Out:
# 2326

# %%
sales.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
#Customer Genders from Canada
sales.loc[sales['Country'] == 'Canada', 'Customer_Gender'].head()
# Out:
# 0     M
# 1     M
# 14    M
# 15    M
# 16    M
# Name: Customer_Gender, dtype: object

# %% [markdown]
# ## Practise these on other spreadsheets.
