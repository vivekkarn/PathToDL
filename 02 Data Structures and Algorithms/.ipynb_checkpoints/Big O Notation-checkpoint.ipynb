# %% [markdown]
# # Big O Notation
# is a simple way of measuring the code's efficiency in the runtime. Its a way of saying how is our codes proportional to the input size in terms of time and speed. We usually look at the worst case.

# %%
#For example the following code runs in O(1)
def func0(n):
    print(n)

# %%
func0(5)
# Out:
# 5

# %%
#O(n)
def func1(n):
    for i in range(0,n):
        print(i)

# %%
func1(5)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#O(n)
def func2(n):
    for i in range(0,n):
        for j in range(0,i):
            print(i,j)

# %%
func2(5)
# Out:
# 1 0
# 2 0
# 2 1
# 3 0
# 3 1
# 3 2
# 4 0
# 4 1
# 4 2
# 4 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### For detail information, look at https://www.youtube.com/embed/v4cd1O4zkGw
# <iframe width="560" height="315" src="https://www.youtube.com/embed/v4cd1O4zkGw" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ![image.png](attachment:image.png)
